# %%
# !pip install -qU langchain langgraph langchain_community
# !pip install -qU langchain_groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.3 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate
import os
from google.colab import userdata
os.environ["GROQ_API_KEY"]=userdata.get("GROQ_API_KEY")

# %%
llm=ChatGroq(model="qwen/qwen3.8-27b", temperature=0, max_tokens=200)
llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.4', 'langchain': '1.4.2'}}, client=<groq.resources.chat.completions.Completions object at 0x7c4f5bcf0440>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x7c4f5bcf1160>, model_name='qwen/qwen3.8-27b', temperature=1e-08, model_kwargs={}, groq_api_key=SecretStr('**********'), max_tokens=200)

# %%
#from langchain_core.prompts import ChatPromptTemplate
my_prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful assistant that helps to create and curate posts for a social media platform."),
        ("human","I want to create a post about {topic}")
    ]
)

# %% [markdown]
# #Chain With Prompts

# %%
chain = my_prompt | llm

# %%
chain.invoke({"topic": "The importance of data privacy in the digital age"})
# Out:
# AIMessage(content='Here are a few options for your post, tailored to different tones and platforms. You can choose the one that best fits your brand voice or audience.\n\n### Option 1: Professional & Insightful (Best for LinkedIn)\n**Headline:** Your Data is Your Digital Footprint. Are You Protecting It?\n\nIn the digital age, data is often called the "new oil." But unlike oil, data is personal. Every click, search, and purchase creates a trail that defines who we are online.\n\nWhy does data privacy matter more than ever?\n🔒 **Security:** Protecting yourself from identity theft and fraud.\n🔒 **Autonomy:** Deciding who sees your information and how it’s used.\n🔒 **Trust:** Building a relationship with brands that respect your boundaries.\n\nAs consumers, we have the power to demand transparency. As businesses, we have the responsibility to protect user data with integrity.\n\nLet’s make privacy a priority', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 200, 'prompt_tokens': 52, 'total_tokens': 252, 'completion_time': 0.416382348, 'completion_tokens_details': None, 'prompt_time': 0.004021666, 'prompt_tokens_details': None, 'queue_time': 0.032176734, 'total_time': 0.420404014}, 'model_name': 'qwen/qwen3.8-27b', 'system_fingerprint': 'fp_c7e30c203c', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a0cce1-0926-7533-bc24-cf3729b0a6bc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 200, 'total_tokens': 252})
