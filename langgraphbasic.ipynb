# %%
import sys

print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]

# %%
# %pip install -q -U langchain langgraph
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 4.7 MB/s eta 0:00:00

# %%
# %pip install -q -U langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 5.1 MB/s eta 0:00:00

# %%
import importlib.metadata

print("LangChain:", importlib.metadata.version("langchain"))
print("LangGraph:", importlib.metadata.version("langgraph"))
# Out:
# LangChain: 1.4.0
# LangGraph: 1.2.11

# %%
# %pip install -q python-dotenv

# %%
from dotenv import load_dotenv

# %%
from groq import Groq
import os

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# openai/gpt-oss-20b
# canopylabs/orpheus-arabic-saudi
# groq/compound
# openai/gpt-oss-safeguard-20b
# allam-2-7b
# meta-llama/llama-prompt-guard-2-86m
# canopylabs/orpheus-v1-english
# whisper-large-v3
# openai/gpt-oss-120b
# whisper-large-v3-turbo
# qwen/qwen3.6-27b
# groq/compound-mini
# meta-llama/llama-prompt-guard-2-22m
# qwen/qwen3.8-27b

# %%
import os
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY").strip()

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="qwen/qwen3.8-27b",
    temperature=0,
    max_tokens=500
)

# %%
response = llm.invoke("Explain LangChain in one sentence.")
print(response.content)
# Out:
# LangChain is a development framework that simplifies the creation of applications powered by large language models by providing modular tools for chaining together prompts, models, and external data sources.
